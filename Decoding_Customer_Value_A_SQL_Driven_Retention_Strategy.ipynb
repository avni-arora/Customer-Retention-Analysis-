# %% [markdown]
# <a href="https://colab.research.google.com/github/avni-arora/Customer-Retention-Analysis-/blob/main/Decoding_Customer_Value_A_SQL_Driven_Retention_Strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from google.colab import drive

df = pd.read_csv('/content/drive/MyDrive/Dataset.csv')
df.shape
df.info()
df.describe()
df.head()
df.duplicated()
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB
# np.int64(0)

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'object']
num_col = [col for col in df.columns if df[col].dtype != 'object']
print(cat_col)
print(num_col)
# Out:
# ['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color', 'Season', 'Subscription Status', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Payment Method', 'Frequency of Purchases']
# ['Customer ID', 'Age', 'Purchase Amount (USD)', 'Review Rating', 'Previous Purchases']

# %%
df = df.drop(columns=['Item Purchased','Color','Size'], axis=1)
df.describe(include='all')
# Out:
#         Customer ID          Age Gender  Category  Purchase Amount (USD)  \
# count   3900.000000  3900.000000   3900      3900            3900.000000
# unique          NaN          NaN      2         4                    NaN
# top             NaN          NaN   Male  Clothing                    NaN
# freq            NaN          NaN   2652      1737                    NaN
# mean    1950.500000    44.068462    NaN       NaN              59.764359
# std     1125.977353    15.207589    NaN       NaN              23.685392
# min        1.000000    18.000000    NaN       NaN              20.000000
# 25%      975.750000    31.000000    NaN       NaN              39.000000
# 50%     1950.500000    44.000000    NaN       NaN              60.000000
# 75%     2925.250000    57.000000    NaN       NaN              81.000000
# max     3900.000000    70.000000    NaN       NaN             100.000000
#
#        Location  Season  Review Rating Subscription Status  Shipping Type  \
# count      3900    3900    3863.000000                3900           3900
# unique       50       4            NaN                   2              6
# top     Montana  Spring            NaN                  No  Free Shipping
# freq         96     999            NaN                2847            675
# mean        NaN     NaN       3.750065                 NaN            NaN
# std         NaN     NaN       0.716983                 NaN            NaN
# min         NaN     NaN       2.500000                 NaN            NaN
# 25%         NaN     NaN       3.100000                 NaN            NaN
# 50%         NaN     NaN       3.800000                 NaN            NaN
# 75%         NaN     NaN       4.400000                 NaN            NaN
# max         NaN     NaN       5.000000                 NaN            NaN
#
#        Discount Applied Promo Code Used  Previous Purchases Payment Method  \
# count              3900            3900         3900.000000           3900
# unique                2               2                 NaN              6
# top                  No              No                 NaN         PayPal
# freq               2223            2223                 NaN            677
# mean                NaN             NaN           25.351538            NaN
# std                 NaN             NaN           14.447125            NaN
# min                 NaN             NaN            1.000000            NaN
# 25%                 NaN             NaN           13.000000            NaN
# 50%                 NaN             NaN           25.000000            NaN
# 75%                 NaN             NaN           38.000000            NaN
# max                 NaN             NaN           50.000000            NaN
#
#        Frequency of Purchases
# count                    3900
# unique                      7
# top            Every 3 Months
# freq                      584
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
df['Review Rating'] = df['Review Rating'].fillna(df['Review Rating'].mean().round(2))
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
sns.boxplot(x=df['Purchase Amount (USD)'])
# Out:
# <Axes: xlabel='Purchase Amount (USD)'>

# %%
sns.boxplot(x=df['Previous Purchases'])
# Out:
# <Axes: xlabel='Previous Purchases'>

# %%
colx = ["Gender", "Category", "Location","Season", "Shipping Type", "Payment Method","Frequency of Purchases"]

for col in colx:
    unique_categories = pd.unique(df[col])

    print(f"{col}: {unique_categories}\n")
# Out:
# Gender: ['Male' 'Female']
#
# Category: ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
#
# Location: ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
#  'Montana' 'Louisiana' 'West Virginia' 'Missouri' 'Arkansas' 'Hawaii'
#  'Delaware' 'New Hampshire' 'New York' 'Alabama' 'Mississippi'
#  'North Carolina' 'California' 'Oklahoma' 'Florida' 'Texas' 'Nevada'
#  'Kansas' 'Colorado' 'North Dakota' 'Illinois' 'Indiana' 'Arizona'
#  'Alaska' 'Tennessee' 'Ohio' 'New Jersey' 'Maryland' 'Vermont'
#  'New Mexico' 'South Carolina' 'Idaho' 'Pennsylvania' 'Connecticut' 'Utah'
#  'Virginia' 'Georgia' 'Nebraska' 'Iowa' 'South Dakota' 'Minnesota'
#  'Washington' 'Wisconsin' 'Michigan']
#
# Season: ['Winter' 'Spring' 'Summer' 'Fall']
#
# Shipping Type: ['Express' 'Free Shipping' 'Next Day Air' 'Standard' '2-Day Shipping'
#  'Store Pickup']
#
# Payment Method: ['Venmo' 'Cash' 'Credit Card' 'PayPal' 'Bank Transfer' 'Debit Card']
#
# Frequency of Purchases: ['Fortnightly' 'Weekly' 'Annually' 'Quarterly' 'Bi-Weekly' 'Monthly'
#  'Every 3 Months']

# %%
df['Subscription Status'] = df['Subscription Status'].map({
    'Yes': 1,
    'No': 0
})

freq = {
   'Fortnightly':3,
   'Weekly':2,
   'Annually':7,
   'Quarterly':6,
   'Bi-Weekly':1,
   'Monthly':4,
   'Every 3 Months':5
}

df['Frequency of Purchases'] = df['Frequency of Purchases'].map(freq)

df['Discount Applied'] = df['Discount Applied'].map({
    'Yes': 1,
    'No': 0
})

df['Promo Code Used'] = df['Promo Code Used'].map({
    'Yes': 1,
    'No': 0
})

# %%
df.head(20)
# Out:
#     Customer ID  Age Gender     Category  Purchase Amount (USD)  \
# 0             1   55   Male     Clothing                     53
# 1             2   19   Male     Clothing                     64
# 2             3   50   Male     Clothing                     73
# 3             4   21   Male     Footwear                     90
# 4             5   45   Male     Clothing                     49
# 5             6   46   Male     Footwear                     20
# 6             7   63   Male     Clothing                     85
# 7             8   27   Male     Clothing                     34
# 8             9   26   Male    Outerwear                     97
# 9            10   57   Male  Accessories                     31
# 10           11   53   Male     Footwear                     34
# 11           12   30   Male     Clothing                     68
# 12           13   61   Male    Outerwear                     72
# 13           14   65   Male     Clothing                     51
# 14           15   64   Male    Outerwear                     53
# 15           16   64   Male     Clothing                     81
# 16           17   25   Male  Accessories                     36
# 17           18   53   Male     Clothing                     38
# 18           19   52   Male     Clothing                     48
# 19           20   66   Male     Clothing                     90
#
#          Location  Season  Review Rating  Subscription Status   Shipping Type  \
# 0        Kentucky  Winter            3.1                    1         Express
# 1           Maine  Winter            3.1                    1         Express
# 2   Massachusetts  Spring            3.1                    1   Free Shipping
# 3    Rhode Island  Spring            3.5                    1    Next Day Air
# 4          Oregon  Spring            2.7                    1   Free Shipping
# 5         Wyoming  Summer            2.9                    1        Standard
# 6         Montana    Fall            3.2                    1   Free Shipping
# 7       Louisiana  Winter            3.2                    1   Free Shipping
# 8   West Virginia  Summer            2.6                    1         Express
# 9        Missouri  Spring            4.8                    1  2-Day Shipping
# 10       Arkansas    Fall            4.1                    1    Store Pickup
# 11         Hawaii  Winter            4.9                    1    Store Pickup
# 12       Delaware  Winter            4.5                    1         Express
# 13  New Hampshire  Spring            4.7                    1         Express
# 14       New York  Winter            4.7                    1   Free Shipping
# 15   Rhode Island  Winter            2.8                    1    Store Pickup
# 16        Alabama  Spring            4.1                    1    Next Day Air
# 17    Mississippi  Winter            4.7                    1  2-Day Shipping
# 18        Montana  Summer            4.6                    1   Free Shipping
# 19   Rhode Island  Summer            3.3                    1        Standard
#
#     Discount Applied  Promo Code Used  Previous Purchases Payment Method  \
# 0                  1                1                  14          Venmo
# 1                  1                1                   2           Cash
# 2                  1                1                  23    Credit Card
# 3                  1                1                  49         PayPal
# 4                  1                1                  31         PayPal
# 5                  1                1                  14          Venmo
# 6                  1                1                  49           Cash
# 7                  1                1                  19    Credit Card
# 8                  1                1                   8          Venmo
# 9                  1                1                   4           Cash
# 10                 1                1                  26  Bank Transfer
# 11                 1                1                  10  Bank Transfer
# 12                 1                1                  37          Venmo
# 13                 1                1                  31         PayPal
# 14                 1                1                  34     Debit Card
# 15                 1                1                   8         PayPal
# 16                 1                1                  44     Debit Card
# 17                 1                1                  36          Venmo
# 18                 1                1                  17           Cash
# 19                 1                1                  46     Debit Card
#
#     Frequency of Purchases
# 0                        3
# 1                        3
# 2                        2
# 3                        2
# 4                        7
# 5                        2
# 6                        6
# 7                        2
# 8                        7
# 9                        6
# 10                       1
# 11                       3
# 12                       3
# 13                       2
# 14                       2
# 15                       4
# 16                       1
# 17                       6
# 18                       2
# 19                       1

# %% [markdown]
# ##CUSTOMER METRICS

# %% [markdown]
# #### 1. Promo Dependency

# %%
df['Promo Dependency'] = (df['Discount Applied'] + df['Promo Code Used'])
df['Promo Dependency'] = df['Promo Dependency'].fillna(0)

df.sample(5)
# Out:
#       Customer ID  Age  Gender     Category  Purchase Amount (USD)  \
# 3533         3534   50  Female     Footwear                     98
# 1935         1936   19    Male     Clothing                     68
# 1547         1548   46    Male  Accessories                     46
# 2944         2945   50  Female     Footwear                     95
# 1629         1630   35    Male     Clothing                     88
#
#             Location  Season  Review Rating  Subscription Status  \
# 3533           Texas    Fall            4.7                    0
# 1935  North Carolina  Spring            4.8                    0
# 1547  South Carolina  Summer            3.5                    0
# 2944        New York  Summer            3.9                    0
# 1629    North Dakota  Spring            3.3                    0
#
#       Shipping Type  Discount Applied  Promo Code Used  Previous Purchases  \
# 3533       Standard                 0                0                  30
# 1935  Free Shipping                 0                0                  45
# 1547       Standard                 1                1                  40
# 2944  Free Shipping                 0                0                   4
# 1629   Next Day Air                 1                1                  13
#
#      Payment Method  Frequency of Purchases  Promo Dependency
# 3533          Venmo                       3                 0
# 1935           Cash                       3                 0
# 1547           Cash                       6                 2
# 2944          Venmo                       5                 0
# 1629          Venmo                       6                 2

# %% [markdown]
# ####2. Customer Lifetime Value (Proxy)

# %%
df['CLV Proxy'] = df['Purchase Amount (USD)'] * df['Frequency of Purchases'] * df['Previous Purchases']
df['CLV Proxy'] = df['CLV Proxy'].fillna(0)

df.sample(5)
# Out:
#       Customer ID  Age  Gender     Category  Purchase Amount (USD)  \
# 934           935   45    Male     Clothing                     47
# 527           528   21    Male     Clothing                     23
# 307           308   29    Male  Accessories                     32
# 497           498   43    Male     Footwear                     39
# 2896         2897   30  Female     Clothing                     91
#
#             Location  Season  Review Rating  Subscription Status  \
# 934           Oregon  Spring            3.7                    1
# 527   South Carolina  Winter            4.3                    1
# 307          Florida  Winter            3.2                    1
# 497         Oklahoma  Winter            4.6                    1
# 2896        Delaware  Summer            3.3                    0
#
#       Shipping Type  Discount Applied  Promo Code Used  Previous Purchases  \
# 934         Express                 1                1                  21
# 527    Next Day Air                 1                1                  47
# 307   Free Shipping                 1                1                   3
# 497   Free Shipping                 1                1                  31
# 2896  Free Shipping                 0                0                   2
#
#      Payment Method  Frequency of Purchases  Promo Dependency  CLV Proxy
# 934   Bank Transfer                       4                 2       3948
# 527   Bank Transfer                       5                 2       5405
# 307     Credit Card                       5                 2        480
# 497            Cash                       2                 2       2418
# 2896          Venmo                       5                 0        910

# %% [markdown]
# ####3. Loyal Customer Score

# %%
df['Previous Purchases'].describe()
# Out:
# count    3900.000000
# mean       25.351538
# std        14.447125
# min         1.000000
# 25%        13.000000
# 50%        25.000000
# 75%        38.000000
# max        50.000000
# Name: Previous Purchases, dtype: float64

# %%
df['Loyal Customer'] = ((df['Previous Purchases'] > df['Previous Purchases'].mean()) & (df['Promo Dependency'] == 0)).astype(int)

loyal_customer_rate = df['Loyal Customer'].mean()*100
# loyal_customer_rate = ((df['Loyal Customer']==1).sum() / df['Customer ID'].count())*100
print(loyal_customer_rate)

df[df['Loyal Customer'] == 1].sample(5)
# Out:
# 28.282051282051285
#       Customer ID  Age  Gender  Category  Purchase Amount (USD)      Location  \
# 2429         2430   57    Male  Footwear                     57      Virginia
# 3778         3779   25  Female  Footwear                     60  South Dakota
# 2988         2989   69  Female  Clothing                     55        Nevada
# 1791         1792   62    Male  Clothing                     98       Montana
# 3312         3313   55  Female  Footwear                     75     Louisiana
#
#       Season  Review Rating  Subscription Status   Shipping Type  \
# 2429  Summer            4.4                    0        Standard
# 3778    Fall            2.9                    0   Free Shipping
# 2988  Spring            5.0                    0  2-Day Shipping
# 1791  Winter            4.0                    0    Store Pickup
# 3312  Summer            3.9                    0    Next Day Air
#
#       Discount Applied  Promo Code Used  Previous Purchases Payment Method  \
# 2429                 0                0                  47    Credit Card
# 3778                 0                0                  30     Debit Card
# 2988                 0                0                  31     Debit Card
# 1791                 0                0                  38           Cash
# 3312                 0                0                  45           Cash
#
#       Frequency of Purchases  Promo Dependency  CLV Proxy  Loyal Customer
# 2429                       3                 0       8037               1
# 3778                       7                 0      12600               1
# 2988                       4                 0       6820               1
# 1791                       7                 0      26068               1
# 3312                       6                 0      20250               1

# %% [markdown]
# ###4. Satisfaction Flag and CSAT (Proxy)

# %%
df['Review Rating'].describe()
# Out:
# count    3900.000000
# mean        3.750064
# std         0.713573
# min         2.500000
# 25%         3.100000
# 50%         3.750000
# 75%         4.400000
# max         5.000000
# Name: Review Rating, dtype: float64

# %%
df['Satisfaction Tier'] = (df['Review Rating'] > df['Review Rating'].mean()).astype(int)

csat_proxy = df['Satisfaction Tier'].mean()*100
# csat_proxy = ((df['Satisfaction Tier']==1).sum()/ df['Customer ID'].count())*100
print(csat_proxy)

df[['Review Rating', 'Satisfaction Tier']].sample(5)
# Out:
# 49.666666666666664
#       Review Rating  Satisfaction Tier
# 758             4.6                  1
# 3896            4.5                  1
# 3785            3.8                  1
# 472             3.9                  1
# 434             4.0                  1

# %% [markdown]
# ###5. Customer Retention Score (Proxy)

# %%
df['Frequency of Purchases'].describe()
# Out:
# count    3900.000000
# mean        4.042308
# std         2.000129
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max         7.000000
# Name: Frequency of Purchases, dtype: float64

# %%
df['Customer Retention Score'] = ((df['Previous Purchases'] > df['Previous Purchases'].mean()) & (df['Subscription Status'] == 1)).astype(int) & (df['Frequency of Purchases'] > df['Frequency of Purchases'].mean())

crr_proxy = df['Customer Retention Score'].mean()*100
# crr_proxy = ((df['Customer Retention Score']==1).sum() / df['Customer ID'].count())*100
print(crr_proxy)

df[['Customer Retention Rate']].sample(5)
# Out:
# 5.717948717948717
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_984/3214468197.py in <cell line: 0>()
#       5 print(crr_proxy)
#       6
# ----> 7 df[['Customer Retention Rate']].sample(5)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Customer Retention Rate'], dtype='object')] are in the [columns]"

# %%
# df.to_excel("dataset1.xlsx", index=False)
# from google.colab import files
# files.download("dataset1.xlsx")

# %%
# df.to_csv("dataset1.csv", index=False)
# from google.colab import files
# files.download("dataset1.csv")
